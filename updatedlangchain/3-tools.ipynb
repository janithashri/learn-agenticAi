# %% [markdown]
# ### Tools
# ###### Models can request to call tools that perform tasks such as fetching data froma databse , searching the web, or running code. Tools are pairings of :
# ###### 1. A schema, including the name of the tool , a description , and/or argument definition
# ###### 2.A function or coroutine to execute

# %%
import sys
print(sys.executable)
# Out:
# d:\agenticai\.venv\Scripts\python.exe

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

load_dotenv(Path("..") / ".env")
os.environ["GROQ_API_KEY"] = os.getenv("GROK_API_KEY") 
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
import os
from google import genai

# ChatGoogleGenerativeAI has no ListModels — use the Google GenAI client
client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))
for m in client.models.list():
    print(m.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 4
#       1 from langchain_google_genai import ChatGoogleGenerativeAI
#       2
#       3
# ----> 4 ChatGoogleGenerativeAI.ListModels()
#
# File d:\agenticai\.venv\Lib\site-packages\pydantic\_internal\_model_construction.py:290, in ModelMetaclass.__getattr__(self, item)
#     288 if private_attributes and item in private_attributes:
#     289     return private_attributes[item]
# --> 290 raise AttributeError(item)
#
# AttributeError: ListModels

# %%
from langchain.tools import tool

@tool
def get_weather(location: str) -> str:
    """Get the weather at alocation"""
    return f"The weather in {location} is sunny"

model_with_tools = model.bind_tools([get_weather])

# %%
response = model_with_tools.invoke("what is the weather in tokyo?")
print(response)
for tool_call in response.tool_calls:#tool_calls is a list of tool calls made by the model
    print(f"Tool call: {tool_call['name']}")
    print(f"Tool call arguments: {tool_call['args']}")


    #### tool_call is a dictionary containing the name of the tool and the arguments passed to it
    #### the tool_call['name'] is the name of the tool
    #### the tool_call['args'] is the arguments passed to the tool
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File d:\agenticai\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3379, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3378 try:
# -> 3379     response: GenerateContentResponse = self.client.models.generate_content(
#    3380         **request,
#    3381     )
#    3382 except ClientError as e:
#
# File d:\agenticai\.venv\Lib\site-packages\google\genai\models.py:6579, in Models.generate_content(self, model, contents, config)
#    6572     logger.warning(
#    6573         'Tools at indices [%s] are not compatible with automatic function '
#    6574         'calling (AFC). AFC is disabled. If AFC is intended, please '
#    (...)   6577         indices_str,
#    6578     )
# -> 6579   return self._generate_content(
#    6580       model=model, contents=contents, config=parsed_config
#    6581   )
#    6583 remaining_remote_calls_afc = _extra_utils.get_max_remote_calls_afc(
#    6584     parsed_config
#    6585 )
#
# File d:\agenticai\.venv\Lib\site-packages\google\genai\models.py:5028, in Models._generate_content(self, model, contents, config)
#    5026 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5028 response = self._api_client.request(
#    5029     'post', path, request_dict, http_options
#    5030 )
#    5032 if config is not None and getattr(
#    5033     config, 'should_return_http_response', None
#    5034 ):
#
# File d:\agenticai\.venv\Lib\site-packages\google\genai\_api_client.py:1708, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1705 http_request = self._build_request(
#    1706     http_method, path, request_dict, http_options
#    1707 )
# -> 1708 response = self._request(http_request, http_options, stream=False)
#    1709 response_body = (
#    1710     response.response_stream[0] if response.response_stream else ''
#    1711 )
#
# File d:\agenticai\.venv\Lib\site-packages\google\genai\_api_client.py:1493, in BaseApiClient._request(self, http_request, http_options, stream)
#    1492     retry = tenacity.Retrying(**retry_kwargs)
# -> 1493     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1495 return self._retry(self._request_once, http_request, stream)
#
# File d:\agenticai\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File d:\agenticai\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File d:\agenticai\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~\.pyenv\pyenv-win\versions\3.12.3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\.pyenv\pyenv-win\versions\3.12.3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File d:\agenticai\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File d:\agenticai\.venv\Lib\site-packages\google\genai\_api_client.py:1472, in BaseApiClient._request_once(self, http_request, stream)
#    1471   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1472 errors.APIError.raise_for_response(response)
#    1473 return HttpResponse(
#    1474     response.headers, response if stream else [response.text]
#    1475 )
#
# File d:\agenticai\.venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File d:\agenticai\.venv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/google_genai:gemini-2.5-flash-lite is not found for API version v1beta, or is not supported for generateContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 response = model_with_tools.invoke("what is the weather in tokyo?")
#       2 print(response)
#       3 for tool_call in response.tool_calls:#tool_calls is a list of tool calls made by the model
#       4     print(f"Tool call: {tool_call['name']}")
#
# File d:\agenticai\.venv\Lib\site-packages\langchain_core\runnables\base.py:6002, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5995 @override
#    5996 def invoke(
#    5997     self,
#    (...)   6000     **kwargs: Any | None,
#    6001 ) -> Output:
# -> 6002     return self.bound.invoke(
#    6003         input,
#    6004         self._merge_configs(config),
#    6005         **{**self.kwargs, **kwargs},
#    6006     )
#
# File d:\agenticai\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2791, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2788         msg = "Tools are already defined.code_execution tool can't be defined"
#    2789         raise ValueError(msg)
# -> 2791 return super().invoke(input, config, stop=stop, **kwargs)
#
# File d:\agenticai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File d:\agenticai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\agenticai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File d:\agenticai\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\agenticai\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3383, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3379     response: GenerateContentResponse = self.client.models.generate_content(
#    3380         **request,
#    3381     )
#    3382 except ClientError as e:
# -> 3383     _handle_client_error(e, request)
#    3385 return _response_to_result(response)
#
# File d:\agenticai\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:177, in _handle_client_error(e, request)
#     175 model_name = request.get("model", "unknown")
#     176 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 177 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'google_genai:gemini-2.5-flash-lite' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/google_genai:gemini-2.5-flash-lite is not found for API version v1beta, or is not supported for generateContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}

# %% [markdown]
# ### Tool Execution loops

# %%
# model generates tool calls
messages = [{'role': 'user', 'content': 'what is the weather in tokyo?'}]
ai_msg = model_with_tools.invoke(messages)
messages.append(ai_msg)

# execute tool calls and get results
for tool_call in ai_msg.tool_calls:
    tool_reslt= get_weather.invoke(tool_call)
    messages.append(tool_reslt)

# pass results to model for final response
final_response = model.invoke(messages)
print(final_response.text)
# Out:
# I'm just an AI, I don't have have access to real-time weather information. However, I can suggest some ways for you to find out the current weather in Tokyo.
#
# You can check the weather in Tokyo by:
#
# 1. Searching online for "Tokyo weather" or "weather in Tokyo" to get the current weather conditions and forecast.
# 2. Using a weather app on your smartphone, such as Dark Sky or Weather Underground, which can provide you with real-time weather information for Tokyo.
# 3. Checking the website of the Japan Meteorological Agency (JMA) for the latest weather forecast and warnings for Tokyo.
# 4. Looking at a weather website, such as AccuWeather or Weather.com, which can provide you with current weather conditions, forecasts, and warnings for Tokyo.
#
# Please note that the weather in Tokyo can vary depending on the time of year and other factors, so it's always a good idea to check the forecast before planning your activities.
